# %% [markdown]
# ANÁLISIS EJECUTIVO - EDA

# %% [markdown]
# A. Máquinaria
#
# Población total: 100 máquinas monitoreadas de forma continua.
#
# Cantidad de máquinaria por modelo:
# + Modelo 3: 35% (35 unidades)
# + Modelo 4: 32% (32 unidades)
# + Modelo 2: 17% (17 unidades)
# + Modelo 1: 16% (16 unidades)
#
# Antigüedad de las máquinas (age): La edad promedio de las máquinas es de 11.33 años, en un rango de 0 años hasta equipos con 20 años de operación continua.

# %% [markdown]
# B. Errores vs Fallas e intervenciones
#
# Errores registrados (df_errors): Se identificaron 3,919 eventos de error.
# + Tipos de error más frecuentes: Se identificó que los errores más frecuentes fueron el error1 (1010 registros) y error2 (988 registros).
# + Maquinas con mayor recurrencia de errores: Máquina con ID 22 (60 errorres), la máquina con ID 78 (54 errores) y la máquina con ID 99 (54 errores).
#
# Fallas de componentes (df_failures): Se registraron 761 fallas operativas de componentes.
# + Componente más critico: El compontente comp2 representa la mayor tasa de fallas con 259 ocurrencias (34% del total), seguido por comp1 (191 fallas), comp (179 fallas) y comp3 (131 fallas).
# + Máquinas con mayor criticidad: La máquina con ID 99 tiene 19 fallas registradas, seguida de la máquina con ID 98 (16 fallas) y la máquina con ID 22 (15 fallas).
#
# Mantenimientos realizados (df_resumen): Se realizaron 3,286 mantenimientos preventivos. Distribución de sustitución de componentes, se muestra que el componente 2 tiene mayor cantidad de mantenimientos (863), con respecto a los otros componentes, los cuales tienen una cantidad de mantenimiento cercana (comp4 811, comp3 808, comp1 804)
#
# Relación Errores vs Fallas (df_resumen): Se da a entender conforme al gráfico de dispersión que existe una correlación positiva con respecto a la cantidad de errores que emite una máquina y sus fallas de componentes. Las máquinas que presentan mayor volumen de advertencias operativas son las que sufren más averias estructurales por ejemplo las máquinas de ID 22 y 99. Haciendo correctamente el cálculo se estipula que existe una correlación positiva media conforme a lo siguiente ($r \approx 0.53$)

# %% [markdown]
# C. Telemetría y sensores (df_telemetry)
#
# Volumen de datos: 876,100 registros horarios, siendo esta una cobertura completa de 365 días para las 100 máquinas.
#
# Comportamiento de sensores:
# + Voltaje (volt): Media de 170.78 V (Min 97.33 V, Max 255.12 V)
# + Rotación (rotate): Media de 446.61 RPM (Min 138.43 RPM, Max 695.02 RPM)
# + Presión (pressure): Media de 100.86 psi (Min 51.24 psi, Max 185.95 psi)
# + Vibración (vibration): Media de 40.39 m/s2 (Min 14.88 m/s2, Max 76.79 m/s2).
#
# Matriz de correlación de sensores: Con base en el heatmap establecido se puede identificar que la correlación lineal entre los valores de los 4 sensores es prácticamente nula ($r \approx 0.00$). Se confirma con esto que los senores operan de forma independiente y que el desgaste no se detecta de forma directa con las lecturas instántaneas, si no que conforme al tiempo.
